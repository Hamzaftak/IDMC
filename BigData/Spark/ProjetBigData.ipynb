# %% [markdown]
# ## Projet FC Architecture Big data
#
# **PrÃ©sentation**
#
# Le changement dâ€™opÃ©rateur est le cauchemar des opÃ©rateurs tÃ©lÃ©phoniques. L'objectif du projet est de mettre en Å“uvre un pipeline de traitement de donnÃ©es afin de dÃ©terminer  lorsquâ€™il semble probable qu'un abonnÃ© dâ€™un opÃ©rateur va se dÃ©sabonner pour migrer vers un autre opÃ©rateur. Le travail demandÃ© consiste donc Ã  Ãªtre capable dâ€™Ã©tablir un profil permettant dâ€™anticiper un possible dÃ©sabonnement.
#
# On considÃ¨re un ensemble de donnÃ©es qui recense un certain nombre de propriÃ©tÃ©s, et le *churn* permettant de dÃ©finir si il y a eu dÃ©sabonnement ou pas. Le dataset est disponible Ã  [cet URL](http://members.loria.fr/operrin/files/FC-Churn.zip "Dataset").
#
# Le schÃ©ma du dataset est le suivant:
#
# ```
#      "customerID"       "gender"           "SeniorCitizen"
#      "Partner"          "Dependents"       "tenure"
#      "PhoneService"     "MultipleLines"    "InternetService"
#      "OnlineSecurity"   "OnlineBackup"     "DeviceProtection"
#      "TechSupport"      "StreamingTV"      "StreamingMovies"
#      "Contract"         "PaperlessBilling" "PaymentMethod"
#      "MonthlyCharges"   "TotalCharges"     "Churn"
# ```
#
#
# Les Ã©tapes que vous devrez suivre sont les suivantes:
#
# 1. analyse approfondie des donnÃ©es,
# 2. nettoyage et sÃ©lection des *features*,
# 3. modÃ©lisation de la prÃ©diction,
# 4. conclusion sur le ou les modÃ¨les expÃ©rimentÃ©s, et les variables importantes.
#
# On commencera donc par rÃ©aliser une exploration approfondie des donnÃ©es, et on prendra soin de filtrer toutes les donnÃ©es qui ne sont pas valides et utiles (*outliers*).
#
# On rÃ©alisera ensuite, pour les propriÃ©tÃ©s choisies, les transformations nÃ©cessaires Ã  la bonne application de l'algorithme choisi, qui pourra Ãªtre par exemple une rÃ©gression logistique ou une forÃªt alÃ©atoire.
#
# On vous demande de rÃ©aliser les tÃ¢ches suivantes en utilisant PySpark (mise en Å“uvre dâ€™un pipeline et cross validation):
#
# Ã‰tape 1 : Chargement des donnÃ©es/dÃ©finition du schÃ©ma
#
# Ã‰tape 2 : **Exploration**/**visualisation**/**nettoyage** de l'ensemble de donnÃ©es
#
# Ã‰tape 3 : RÃ©alisation des transformations nÃ©cessaires
#
# Ã‰tape 4 : **SÃ©lection des informations**
#
# Ã‰tape 5 : EntraÃ®nement du modÃ¨le (en divisant votre dataset en deux â€“ training et test)
#
# Ã‰tape 6 : **Ã‰valuation des modÃ¨les**
#
# Ã€ lâ€™issue du pipeline, vous donnerez les mesures dâ€™Ã©valuation des diffÃ©rents modÃ¨les expÃ©rimentÃ©s.
#
# **Objectifs & Ã©valuation**
#
# Les objectifs principaux du projet sont les suivants:
#
# - construire un pipeline Spark permettant de mettre en Å“uvre votre algorithme.
# - sÃ©lectionner les meilleures observations (*features*) grÃ¢ce Ã  une analyse prÃ©alable approfondie des donnÃ©es afin de comprendre celles qui peuvent Ãªtre utiles.
# - mettre en Å“uvre diffÃ©rents modÃ¨les.
# - Ã©valuer les modÃ¨les testÃ©s.
#
# **Travail Ã  rendre**
#
# On vous demande de rendre votre projet en envoyant les sources de votre notebook Jupyter, dans lequel vous expliquerez comment vous avez gÃ©rÃ© les diffÃ©rents points pris en compte pour lâ€™Ã©valuation, ainsi que lâ€™analyse demandÃ©e.
